# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_typespeiffic_price(df, property_subtype):
    df_panel = df[df['property_subtype'] == property_subtype]
    return df_panel[['city', 'unit_property_price']].groupby(by=['city'])['unit_property_price'].mean()

def get_statistics(filename = '../data/DataSet_LakasP.csv'):
    df = pd.read_csv(filename)
    df['unit_property_price'] = df.price_created_at / df.property_area
    df_city_gr = df[['city', 'price_created_at', 'unit_property_price']].groupby(by='city')
    mean_unit_property_price = df_city_gr['unit_property_price'].mean().values
    min_price_created_at = df_city_gr['price_created_at'].min()
    max_price_created_at = df_city_gr['price_created_at'].max()
    df_panel_price = get_typespeiffic_price(df, 'prefabricated panel flat (for sale)')
    df_brick_price = get_typespeiffic_price(df, 'brick flat (for sale)')
    df_price_diff = (df_panel_price - df_brick_price).abs()
    return pd.DataFrame({'City': df_price_diff.index,
                         'Avg. m2 price': mean_unit_property_price, 
                         'Min': min_price_created_at,
                         'Max': max_price_created_at,
                         'df_panel_price': df_panel_price,
                         'df_brick_price': df_brick_price,
                         'Panel – brick diff': df_price_diff})

# %%
get_statistics()
# Out:
#                             City  Avg. m2 price  Min   Max  df_panel_price  \
# city
# Budapest I.          Budapest I.       0.564487  1.0  89.9        0.527283
# Budapest II.        Budapest II.       0.529692  1.0  95.0        0.501896
# Budapest III.      Budapest III.       0.372534  2.1  96.0        0.307941
# Budapest IV.        Budapest IV.       0.303773  1.0  68.0        0.284946
# Budapest IX.        Budapest IX.       0.440449  2.0  96.0        0.329711
# Budapest V.          Budapest V.       0.728948  0.5  88.0        0.845024
# Budapest VI.        Budapest VI.       0.524832  1.0  92.4        0.536202
# Budapest VII.      Budapest VII.       0.442014  2.0  88.0        0.430283
# Budapest VIII.    Budapest VIII.       0.348262  2.4  95.0        0.281381
# Budapest X.          Budapest X.       0.272447  2.5  56.9        0.250766
# Budapest XI.        Budapest XI.       0.447294  0.0  78.9        0.352114
# Budapest XII.      Budapest XII.       0.509370  5.5  80.2        0.407579
# Budapest XIII.    Budapest XIII.       0.452849  0.2  80.0        0.359768
# Budapest XIV.      Budapest XIV.       0.373272  3.0  80.0        0.304399
# Budapest XIX.      Budapest XIX.       0.267874  4.0  65.7        0.249429
# Budapest XV.        Budapest XV.       0.285572  4.0  68.9        0.276497
# Budapest XVI.      Budapest XVI.       0.350552  4.5  99.6        0.294522
# Budapest XVII.    Budapest XVII.       0.299107  5.0  85.0        0.257517
# Budapest XVIII.  Budapest XVIII.       0.286047  0.0  87.8        0.232965
# Budapest XX.        Budapest XX.       0.247834  3.0  69.9        0.221074
# Budapest XXI.      Budapest XXI.       0.238354  3.0  78.0        0.228365
# Budapest XXII.    Budapest XXII.       0.314887  0.8  49.9        0.291089
# Budapest XXIII.  Budapest XXIII.       0.258594  3.4  47.9        0.234756
#
#                  df_brick_price  Panel – brick diff
# city
# Budapest I.            0.564709            0.037426
# Budapest II.           0.531880            0.029984
# Budapest III.          0.478615            0.170673
# Budapest IV.           0.331745            0.046799
# Budapest IX.           0.449685            0.119974
# Budapest V.            0.728535            0.116489
# Budapest VI.           0.524853            0.011349
# Budapest VII.          0.441934            0.011651
# Budapest VIII.         0.353757            0.072377
# Budapest X.            0.291144            0.040378
# Budapest XI.           0.496438            0.144324
# Budapest XII.          0.510026            0.102447
# Budapest XIII.         0.471120            0.111352
# Budapest XIV.          0.400750            0.096351
# Budapest XIX.          0.295512            0.046083
# Budapest XV.           0.315984            0.039486
# Budapest XVI.          0.364449            0.069927
# Budapest XVII.         0.362719            0.105202
# Budapest XVIII.        0.322584            0.089618
# Budapest XX.           0.263274            0.042200
# Budapest XXI.          0.252239            0.023874
# Budapest XXII.         0.337936            0.046847
# Budapest XXIII.        0.270342            0.035586

# %%
def get_data_cleaning_helper(filename = '../data/DataSet_LakasP.csv'):
    df = pd.read_csv(filename)
    assert not df.price_created_at.isnull().any()
    df['unit_property_price'] = df.price_created_at / df.property_area
    df_panel_price = get_typespeiffic_price(df, 'prefabricated panel flat (for sale)')
    df_brick_price = get_typespeiffic_price(df, 'brick flat (for sale)')
    df_price = pd.DataFrame({'unit_property_price_panel': df_panel_price, 'unit_property_price_brick': df_brick_price})

    df_null = df[df.property_subtype.isnull()]
    df_join_pr = df_null.join(df_price, on='city')
    return pd.DataFrame({'City': df_join_pr.city,
                         'Property_subtype': df_join_pr.property_subtype,
                         'Property_area': df_join_pr.property_area,
                         'Price_created_at': df_join_pr.price_created_at,
                         'Avg. m2 price': df_join_pr.unit_property_price,
                         'Avg. m2 price panel': df_join_pr.unit_property_price_panel,
                         'Avg. m2 price brick': df_join_pr.unit_property_price_brick})

# %%
df = get_data_cleaning_helper()
get_diff = lambda x: (df['Avg. m2 price'] - df[x]).abs()
df['is_panel'] = get_diff('Avg. m2 price panel') < get_diff('Avg. m2 price brick')
df
# Out:
#                   City Property_subtype  Property_area  Price_created_at  \
# 51        Budapest XX.              NaN           65.0              15.5
# 119       Budapest XX.              NaN           55.0               9.5
# 314       Budapest IX.              NaN           50.0              12.9
# 359     Budapest XXII.              NaN           50.0              13.0
# 455      Budapest XIV.              NaN           50.0              13.2
# 465        Budapest X.              NaN           50.0              11.6
# 476        Budapest X.              NaN           65.0              10.9
# 607    Budapest XVIII.              NaN           50.0               9.9
# 827      Budapest XIX.              NaN           55.0              10.7
# 913     Budapest VIII.              NaN           60.0              12.7
# 925      Budapest XIV.              NaN           60.0              16.0
# 938       Budapest XX.              NaN           35.0               8.0
# 1002     Budapest XIV.              NaN           40.0              13.5
# 1105   Budapest XVIII.              NaN           50.0               9.5
# 1154       Budapest X.              NaN           25.0               6.6
# 1212     Budapest XVI.              NaN           70.0              16.0
# 1291    Budapest XVII.              NaN           65.0              10.9
# 1415     Budapest XVI.              NaN           50.0              13.1
# 1519      Budapest XX.              NaN           35.0               9.9
# 1595     Budapest XIV.              NaN           60.0              15.9
# 1612      Budapest II.              NaN           55.0              19.5
# 1707      Budapest IX.              NaN           55.0              12.1
# 1731      Budapest XV.              NaN           25.0               7.7
# 1942    Budapest XXII.              NaN           45.0              11.0
# 2103      Budapest XV.              NaN           65.0              15.9
# 2200     Budapest XIV.              NaN           50.0              13.9
# 2236    Budapest XVII.              NaN           70.0              12.0
# 2286       Budapest X.              NaN           50.0              12.7
# 2325      Budapest XX.              NaN           60.0              15.3
# 2378    Budapest XIII.              NaN           45.0              14.5
# ...                ...              ...            ...               ...
# 77381     Budapest XI.              NaN           55.0              27.9
# 77396     Budapest XX.              NaN           65.0              14.0
# 77407      Budapest X.              NaN           65.0              14.8
# 77538    Budapest XIV.              NaN           35.0              11.5
# 77565    Budapest XIX.              NaN           45.0              13.5
# 77574    Budapest XXI.              NaN           55.0              13.7
# 77578    Budapest XIX.              NaN           45.0              13.5
# 77604     Budapest XX.              NaN           55.0              12.7
# 77662  Budapest XVIII.              NaN           45.0              12.5
# 77686     Budapest IX.              NaN           55.0              18.9
# 77690  Budapest XVIII.              NaN           45.0              12.5
# 77695  Budapest XVIII.              NaN           45.0              12.5
# 77717     Budapest XX.              NaN           55.0              12.9
# 77724     Budapest XX.              NaN           50.0              11.9
